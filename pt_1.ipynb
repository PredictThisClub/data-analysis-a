# %%
import pandas as pd

# %%
df = pd.read_csv("abnb.csv", index_col=0) #shows index otherwise
df.head()
# Out:
#                                                     host_name  \
# name
# Clean & quiet apt home by the park                       John
# Skylit Midtown Castle                                Jennifer
# THE VILLAGE OF HARLEM....NEW YORK !                 Elisabeth
# Cozy Entire Floor of Brownstone                   LisaRoxanne
# Entire Apt: Spacious Studio/Loft by central park        Laura
#
#                                                  neighbourhood_group  \
# name
# Clean & quiet apt home by the park                          Brooklyn
# Skylit Midtown Castle                                      Manhattan
# THE VILLAGE OF HARLEM....NEW YORK !                        Manhattan
# Cozy Entire Floor of Brownstone                             Brooklyn
# Entire Apt: Spacious Studio/Loft by central park           Manhattan
#
#                                                  neighbourhood  latitude  \
# name
# Clean & quiet apt home by the park                  Kensington  40.64749
# Skylit Midtown Castle                                  Midtown  40.75362
# THE VILLAGE OF HARLEM....NEW YORK !                     Harlem  40.80902
# Cozy Entire Floor of Brownstone                   Clinton Hill  40.68514
# Entire Apt: Spacious Studio/Loft by central park   East Harlem  40.79851
#
#                                                   longitude        room_type  \
# name
# Clean & quiet apt home by the park                -73.97237     Private room
# Skylit Midtown Castle                             -73.98377  Entire home/apt
# THE VILLAGE OF HARLEM....NEW YORK !               -73.94190     Private room
# Cozy Entire Floor of Brownstone                   -73.95976  Entire home/apt
# Entire Apt: Spacious Studio/Loft by central park  -73.94399  Entire home/apt
#
#                                                   price  minimum_nights  \
# name
# Clean & quiet apt home by the park                  149               1
# Skylit Midtown Castle                               225               1
# THE VILLAGE OF HARLEM....NEW YORK !                 150               3
# Cozy Entire Floor of Brownstone                      89               1
# Entire Apt: Spacious Studio/Loft by central park     80              10
#
#                                                   number_of_reviews  \
# name
# Clean & quiet apt home by the park                                9
# Skylit Midtown Castle                                            45
# THE VILLAGE OF HARLEM....NEW YORK !                               0
# Cozy Entire Floor of Brownstone                                 270
# Entire Apt: Spacious Studio/Loft by central park                  9
#
#                                                  reviews_per_month  \
# name
# Clean & quiet apt home by the park                            0.21
# Skylit Midtown Castle                                         0.38
# THE VILLAGE OF HARLEM....NEW YORK !                            NaN
# Cozy Entire Floor of Brownstone                               4.64
# Entire Apt: Spacious Studio/Loft by central park               0.1
#
#                                                   calculated_host_listings_count  \
# name
# Clean & quiet apt home by the park                                             6
# Skylit Midtown Castle                                                          2
# THE VILLAGE OF HARLEM....NEW YORK !                                            1
# Cozy Entire Floor of Brownstone                                                1
# Entire Apt: Spacious Studio/Loft by central park                               1
#
#                                                   availability_365
# name
# Clean & quiet apt home by the park                             365
# Skylit Midtown Castle                                          355
# THE VILLAGE OF HARLEM....NEW YORK !                            365
# Cozy Entire Floor of Brownstone                                194
# Entire Apt: Spacious Studio/Loft by central park                 0

# %%
df.tail()
# Out:
#                                                        host_name  \
# name
# Charming one bedroom - newly renovated rowhouse          Sabrina
# Affordable room in Bushwick/East Williamsburg            Marisol
# Sunny Studio at Historical Neighborhood            Ilgar & Aysel
# 43rd St. Time Square-cozy single bed                         Taz
# Trendy duplex in the very heart of Hell's Kitchen     Christophe
#
#                                                   neighbourhood_group  \
# name
# Charming one bedroom - newly renovated rowhouse              Brooklyn
# Affordable room in Bushwick/East Williamsburg                Brooklyn
# Sunny Studio at Historical Neighborhood                     Manhattan
# 43rd St. Time Square-cozy single bed                        Manhattan
# Trendy duplex in the very heart of Hell's Kitchen           Manhattan
#
#                                                         neighbourhood  \
# name
# Charming one bedroom - newly renovated rowhouse    Bedford-Stuyvesant
# Affordable room in Bushwick/East Williamsburg                Bushwick
# Sunny Studio at Historical Neighborhood                        Harlem
# 43rd St. Time Square-cozy single bed                   Hell's Kitchen
# Trendy duplex in the very heart of Hell's Kitchen      Hell's Kitchen
#
#                                                    latitude  longitude  \
# name
# Charming one bedroom - newly renovated rowhouse    40.67853  -73.94995
# Affordable room in Bushwick/East Williamsburg      40.70184  -73.93317
# Sunny Studio at Historical Neighborhood            40.81475  -73.94867
# 43rd St. Time Square-cozy single bed               40.75751  -73.99112
# Trendy duplex in the very heart of Hell's Kitchen  40.76404  -73.98933
#
#                                                          room_type  price  \
# name
# Charming one bedroom - newly renovated rowhouse       Private room     70
# Affordable room in Bushwick/East Williamsburg         Private room     40
# Sunny Studio at Historical Neighborhood            Entire home/apt    115
# 43rd St. Time Square-cozy single bed                   Shared room     55
# Trendy duplex in the very heart of Hell's Kitchen     Private room     90
#
#                                                    minimum_nights  \
# name
# Charming one bedroom - newly renovated rowhouse                 2
# Affordable room in Bushwick/East Williamsburg                   4
# Sunny Studio at Historical Neighborhood                        10
# 43rd St. Time Square-cozy single bed                            1
# Trendy duplex in the very heart of Hell's Kitchen               7
#
#                                                    number_of_reviews  \
# name
# Charming one bedroom - newly renovated rowhouse                    0
# Affordable room in Bushwick/East Williamsburg                      0
# Sunny Studio at Historical Neighborhood                            0
# 43rd St. Time Square-cozy single bed                               0
# Trendy duplex in the very heart of Hell's Kitchen                  0
#
#                                                   reviews_per_month  \
# name
# Charming one bedroom - newly renovated rowhouse                 NaN
# Affordable room in Bushwick/East Williamsburg                   NaN
# Sunny Studio at Historical Neighborhood                         NaN
# 43rd St. Time Square-cozy single bed                            NaN
# Trendy duplex in the very heart of Hell's Kitchen               NaN
#
#                                                    calculated_host_listings_count  \
# name
# Charming one bedroom - newly renovated rowhouse                                 2
# Affordable room in Bushwick/East Williamsburg                                   2
# Sunny Studio at Historical Neighborhood                                         1
# 43rd St. Time Square-cozy single bed                                            6
# Trendy duplex in the very heart of Hell's Kitchen                               1
#
#                                                    availability_365
# name
# Charming one bedroom - newly renovated rowhouse                   9
# Affordable room in Bushwick/East Williamsburg                    36
# Sunny Studio at Historical Neighborhood                          27
# 43rd St. Time Square-cozy single bed                              2
# Trendy duplex in the very heart of Hell's Kitchen                23

# %%
df1=df.set_index("neighbourhood_group")
df1 = df1[df1['reviews_per_month']!="NaN"]
df1.head()
# Out:
#                        host_name neighbourhood  latitude  longitude  \
# neighbourhood_group
# Brooklyn                    John    Kensington  40.64749  -73.97237
# Manhattan               Jennifer       Midtown  40.75362  -73.98377
# Manhattan              Elisabeth        Harlem  40.80902  -73.94190
# Brooklyn             LisaRoxanne  Clinton Hill  40.68514  -73.95976
# Manhattan                  Laura   East Harlem  40.79851  -73.94399
#
#                            room_type  price  minimum_nights  \
# neighbourhood_group
# Brooklyn                Private room    149               1
# Manhattan            Entire home/apt    225               1
# Manhattan               Private room    150               3
# Brooklyn             Entire home/apt     89               1
# Manhattan            Entire home/apt     80              10
#
#                      number_of_reviews reviews_per_month  \
# neighbourhood_group
# Brooklyn                             9              0.21
# Manhattan                           45              0.38
# Manhattan                            0               NaN
# Brooklyn                           270              4.64
# Manhattan                            9               0.1
#
#                      calculated_host_listings_count  availability_365
# neighbourhood_group
# Brooklyn                                          6               365
# Manhattan                                         2               355
# Manhattan                                         1               365
# Brooklyn                                          1               194
# Manhattan                                         1                 0

# %%
df1["price"].plot()

# %%
df1=df1.dropna()

# %%
df1["price"].plot()

# %%
df1["price"].rolling(25).mean().plot()

# %%
df1.sort_index(inplace=True)

# %%
df1["price"].plot()

# %%
df1["price_loc"] = df1["price"].rolling(25).mean() #saving the above df in a  new df

# %%
df2=df.set_index("availability_365")

# %%
df2.head()
# Out:
#                     host_name neighbourhood_group neighbourhood  latitude  \
# availability_365
# 365                      John            Brooklyn    Kensington  40.64749
# 355                  Jennifer           Manhattan       Midtown  40.75362
# 365                 Elisabeth           Manhattan        Harlem  40.80902
# 194               LisaRoxanne            Brooklyn  Clinton Hill  40.68514
# 0                       Laura           Manhattan   East Harlem  40.79851
#
#                   longitude        room_type  price  minimum_nights  \
# availability_365
# 365               -73.97237     Private room    149               1
# 355               -73.98377  Entire home/apt    225               1
# 365               -73.94190     Private room    150               3
# 194               -73.95976  Entire home/apt     89               1
# 0                 -73.94399  Entire home/apt     80              10
#
#                   number_of_reviews reviews_per_month  \
# availability_365
# 365                               9              0.21
# 355                              45              0.38
# 365                               0               NaN
# 194                             270              4.64
# 0                                 9               0.1
#
#                   calculated_host_listings_count
# availability_365
# 365                                            6
# 355                                            2
# 365                                            1
# 194                                            1
# 0                                              1

# %%
df2['neighbourhood_group'].values
# Out:
# array(['Brooklyn', 'Manhattan', 'Manhattan', ..., 'Manhattan',
#        'Manhattan', 'Manhattan'], dtype=object)

# %%
df2['neighbourhood_group'].values.tolist()
# Out:
# ['Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Queens',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Queens',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Queens',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Queens',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Staten Island',
#  'Brooklyn',
#  'Bronx',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Queens',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Queens',
#  'Manhattan',
#  'Brooklyn',
#  'Queens',
#  'Queens',
#  'Queens',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Bronx',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Queens',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Queens',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Staten Island',
#  'Staten Island',
#  'Staten Island',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Staten Island',
#  'Queens',
#  'Brooklyn',
#  'Brooklyn',
#  'Bronx',
#  'Bronx',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Bronx',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Queens',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Queens',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Queens',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Queens',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Queens',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Queens',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Bronx',
#  'Manhattan',
#  'Queens',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Queens',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Queens',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Queens',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Bronx',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Queens',
#  'Queens',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Bronx',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Queens',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Bronx',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Queens',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Staten Island',
#  'Brooklyn',
#  'Queens',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Staten Island',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Bronx',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Queens',
#  'Manhattan',
#  'Manhattan',
#  'Queens',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Queens',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Bronx',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Queens',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Queens',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Queens',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Queens',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Staten Island',
#  'Staten Island',
#  'Staten Island',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Queens',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Queens',
#  'Bronx',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Queens',
#  'Brooklyn',
#  'Queens',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Queens',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Queens',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Queens',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Queens',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Queens',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Staten Island',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Queens',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Staten Island',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Bronx',
#  'Staten Island',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Queens',
#  'Queens',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Queens',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  ...]

# %%
print(set(df2['neighbourhood_group'].values.tolist()))
# Out:
# {'Manhattan', 'Queens', 'Bronx', 'Staten Island', 'Brooklyn'}

# %%
df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
df=df.set_index("neighbourhood_group")
df.plot(figsize=(8,5), legend=True)

# %%
neighbourhood_group = df1.groupby("neighbourhood_group")
neighbourhood_group.get_group("Brooklyn").head(3)
# Out:
#                     host_name       neighbourhood  latitude  longitude  \
# neighbourhood_group
# Brooklyn                 Adam         Fort Greene  40.69401  -73.97300
# Brooklyn              Elliott       Crown Heights  40.67806  -73.94459
# Brooklyn                Julio  Bedford-Stuyvesant  40.69608  -73.94320
#
#                            room_type  price  minimum_nights  \
# neighbourhood_group
# Brooklyn                Private room     62               2
# Brooklyn             Entire home/apt     88               1
# Brooklyn                Private room     45               1
#
#                      number_of_reviews reviews_per_month  \
# neighbourhood_group
# Brooklyn                             3              0.13
# Brooklyn                             2              0.08
# Brooklyn                             4              0.15
#
#                      calculated_host_listings_count  availability_365  \
# neighbourhood_group
# Brooklyn                                          1                 0
# Brooklyn                                          1                 0
# Brooklyn                                          1                 0
#
#                      price_loc
# neighbourhood_group
# Brooklyn                 63.04
# Brooklyn                 63.56
# Brooklyn                 61.96

# %%
g1 = df1.groupby("neighbourhood_group")
g1.get_group("Brooklyn").set_index("minimum_nights").head()
# Out:
#                host_name       neighbourhood  latitude  longitude  \
# minimum_nights
# 2                   Adam         Fort Greene  40.69401  -73.97300
# 1                Elliott       Crown Heights  40.67806  -73.94459
# 1                  Julio  Bedford-Stuyvesant  40.69608  -73.94320
# 12                 Ariel          Park Slope  40.67079  -73.97384
# 2                  Peggy           Flatlands  40.62468  -73.94532
#
#                       room_type  price  number_of_reviews reviews_per_month  \
# minimum_nights
# 2                  Private room     62                  3              0.13
# 1               Entire home/apt     88                  2              0.08
# 1                  Private room     45                  4              0.15
# 12              Entire home/apt    195                  2              0.08
# 2                  Private room     46                  4              0.17
#
#                 calculated_host_listings_count  availability_365  price_loc
# minimum_nights
# 2                                            1                 0      63.04
# 1                                            1                 0      63.56
# 1                                            1                 0      61.96
# 12                                           1                 0      67.16
# 2                                            1                 4      66.00

# %%
g1.describe()
# Out:
#                     latitude                                            \
#                        count       mean       std       min        25%
# neighbourhood_group
# Bronx                  876.0  40.848277  0.026734  40.80011  40.826845
# Brooklyn             16449.0  40.684795  0.027018  40.57115  40.672550
# Manhattan            16638.0  40.765965  0.038990  40.70234  40.731310
# Queens                4572.0  40.731381  0.040608  40.56568  40.707315
# Staten Island          315.0  40.611143  0.031394  40.50641  40.593985
#
#                                                     longitude             ...  \
#                            50%        75%       max     count       mean  ...
# neighbourhood_group                                                       ...
# Bronx                40.847145  40.869250  40.91306     876.0 -73.883848  ...
# Brooklyn             40.686980  40.704390  40.73890   16449.0 -73.951029  ...
# Manhattan            40.761600  40.797450  40.87665   16638.0 -73.973902  ...
# Queens               40.744975  40.759773  40.79721    4572.0 -73.871199  ...
# Staten Island        40.623180  40.634630  40.64779     315.0 -74.104717  ...
#
#                     availability_365        price_loc                         \
#                                  75%    max     count        mean        std
# neighbourhood_group
# Bronx                          318.0  365.0     852.0   79.826854  12.048095
# Brooklyn                       205.0  365.0   16449.0  121.439166  38.820987
# Manhattan                      217.0  365.0   16638.0  180.088561  46.304355
# Queens                         294.0  365.0    4572.0   95.928976  33.029987
# Staten Island                  323.0  365.0     315.0   88.754286  11.285830
#
#
#                         min     25%     50%     75%     max
# neighbourhood_group
# Bronx                 57.80   69.94   78.28   88.00  116.16
# Brooklyn              61.96  102.68  115.64  131.60  664.16
# Manhattan            102.56  152.64  170.32  194.48  587.56
# Queens                56.92   83.16   91.84  101.45  487.52
# Staten Island         61.28   81.32   87.12   94.90  121.44
#
# [5 rows x 64 columns]

# %%
df.describe()
# Out:
#            latitude     longitude         price  minimum_nights  \
# count  48895.000000  48895.000000  48895.000000    48895.000000
# mean      40.728949    -73.952170    152.720687        7.029962
# std        0.054530      0.046157    240.154170       20.510550
# min       40.499790    -74.244420      0.000000        1.000000
# 25%       40.690100    -73.983070     69.000000        1.000000
# 50%       40.723070    -73.955680    106.000000        3.000000
# 75%       40.763115    -73.936275    175.000000        5.000000
# max       40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  calculated_host_listings_count  availability_365
# count       48895.000000                    48895.000000      48895.000000
# mean           23.274466                        7.143982        112.781327
# std            44.550582                       32.952519        131.622289
# min             0.000000                        1.000000          0.000000
# 25%             1.000000                        1.000000          0.000000
# 50%             5.000000                        1.000000         45.000000
# 75%            24.000000                        2.000000        227.000000
# max           629.000000                      327.000000        365.000000
